# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Seen vs Oracle

# %%
keys = []
values = []

seen_vs_oracle_pick = {'backbone.llm.layer_0_step_0': 0.4952491521835327, 'backbone.llm.layer_1_step_0': 0.5157991051673889, 'backbone.llm.layer_2_step_0': 0.7989586591720581, 'backbone.llm.layer_3_step_0': 0.7964445352554321, 'backbone.llm.layer_4_step_0': 0.793404757976532, 'backbone.llm.layer_5_step_0': 0.7747446894645691, 'backbone.llm.layer_6_step_0': 0.8532298803329468, 'backbone.llm.layer_7_step_0': 0.7639457583427429, 'backbone.llm.layer_8_step_0': 0.7562461495399475, 'backbone.llm.layer_9_step_0': 0.7583516240119934, 'backbone.llm.layer_10_step_0': 0.7150312066078186, 'backbone.llm.layer_11_step_0': 0.7247552871704102, 'action_head.dit.layer_0_step_0': 0.10594264417886734, 'action_head.dit.layer_1_step_0': 0.14689961075782776, 'action_head.dit.layer_2_step_0': 0.14158815145492554, 'action_head.dit.layer_3_step_0': 0.18360048532485962, 'action_head.dit.layer_4_step_0': 0.2095501869916916, 'action_head.dit.layer_5_step_0': 0.2614861726760864, 'action_head.dit.layer_6_step_0': 0.28736671805381775, 'action_head.dit.layer_7_step_0': 0.3055378496646881, 'action_head.dit.layer_8_step_0': 0.34515273571014404, 'action_head.dit.layer_9_step_0': 0.36588722467422485, 'action_head.dit.layer_10_step_0': 0.4062516391277313, 'action_head.dit.layer_11_step_0': 0.43343257904052734, 'action_head.dit.layer_12_step_0': 0.3904864490032196, 'action_head.dit.layer_13_step_0': 0.41504961252212524, 'action_head.dit.layer_14_step_0': 0.4459724724292755, 'action_head.dit.layer_15_step_0': 0.3884522616863251, 'action_head.dit.layer_0_step_1': 0.14102283120155334, 'action_head.dit.layer_1_step_1': 0.14539913833141327, 'action_head.dit.layer_2_step_1': 0.18211966753005981, 'action_head.dit.layer_3_step_1': 0.20461714267730713, 'action_head.dit.layer_4_step_1': 0.2593364417552948, 'action_head.dit.layer_5_step_1': 0.28955790400505066, 'action_head.dit.layer_6_step_1': 0.3471775949001312, 'action_head.dit.layer_7_step_1': 0.3680325746536255, 'action_head.dit.layer_8_step_1': 0.4146910309791565, 'action_head.dit.layer_9_step_1': 0.4463900923728943, 'action_head.dit.layer_10_step_1': 0.4760073721408844, 'action_head.dit.layer_11_step_1': 0.5178804993629456, 'action_head.dit.layer_12_step_1': 0.4546286463737488, 'action_head.dit.layer_13_step_1': 0.48175516724586487, 'action_head.dit.layer_14_step_1': 0.48818719387054443, 'action_head.dit.layer_15_step_1': 0.4272262156009674, 'action_head.dit.layer_0_step_2': 0.1815781146287918, 'action_head.dit.layer_1_step_2': 0.211942657828331, 'action_head.dit.layer_2_step_2': 0.2769508957862854, 'action_head.dit.layer_3_step_2': 0.3343084454536438, 'action_head.dit.layer_4_step_2': 0.3820474445819855, 'action_head.dit.layer_5_step_2': 0.4465441107749939, 'action_head.dit.layer_6_step_2': 0.464853972196579, 'action_head.dit.layer_7_step_2': 0.5158876180648804, 'action_head.dit.layer_8_step_2': 0.5441684126853943, 'action_head.dit.layer_9_step_2': 0.5477213263511658, 'action_head.dit.layer_10_step_2': 0.6052274703979492, 'action_head.dit.layer_11_step_2': 0.6377694010734558, 'action_head.dit.layer_12_step_2': 0.532243549823761, 'action_head.dit.layer_13_step_2': 0.5438815951347351, 'action_head.dit.layer_14_step_2': 0.5458007454872131, 'action_head.dit.layer_15_step_2': 0.4557657539844513, 'action_head.dit.layer_0_step_3': 0.32580482959747314, 'action_head.dit.layer_1_step_3': 0.4406994581222534, 'action_head.dit.layer_2_step_3': 0.4920854866504669, 'action_head.dit.layer_3_step_3': 0.5539106130599976, 'action_head.dit.layer_4_step_3': 0.5935154557228088, 'action_head.dit.layer_5_step_3': 0.591130256652832, 'action_head.dit.layer_6_step_3': 0.6376442909240723, 'action_head.dit.layer_7_step_3': 0.6645541787147522, 'action_head.dit.layer_8_step_3': 0.6924514174461365, 'action_head.dit.layer_9_step_3': 0.6930046081542969, 'action_head.dit.layer_10_step_3': 0.7323366403579712, 'action_head.dit.layer_11_step_3': 0.7301748394966125, 'action_head.dit.layer_12_step_3': 0.6147156357765198, 'action_head.dit.layer_13_step_3': 0.612268328666687, 'action_head.dit.layer_14_step_3': 0.6395276188850403, 'action_head.dit.layer_15_step_3': 0.5286993384361267}

for k, v in seen_vs_oracle_pick.items():
    keys.append(k)
    values.append(v)

# 그래프 생성
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(keys, values, marker='o', linewidth=2, label='Frames ~ Pick process')

# x축 라벨 설정 및 회전
ax.set_xticks(range(len(keys)))
ax.set_xticklabels(keys, rotation=90)
        


seen_vs_oracle_place = {'backbone.llm.layer_0_step_0': 0.5029518008232117, 'backbone.llm.layer_1_step_0': 0.5223961472511292, 'backbone.llm.layer_2_step_0': 0.8013736009597778, 'backbone.llm.layer_3_step_0': 0.7984004020690918, 'backbone.llm.layer_4_step_0': 0.7917571663856506, 'backbone.llm.layer_5_step_0': 0.778992235660553, 'backbone.llm.layer_6_step_0': 0.776147186756134, 'backbone.llm.layer_7_step_0': 0.7702391147613525, 'backbone.llm.layer_8_step_0': 0.7364890575408936, 'backbone.llm.layer_9_step_0': 0.7422598600387573, 'backbone.llm.layer_10_step_0': 0.720199704170227, 'backbone.llm.layer_11_step_0': 0.727385401725769, 'action_head.dit.layer_0_step_0': 0.11355985701084137, 'action_head.dit.layer_1_step_0': 0.14806637167930603, 'action_head.dit.layer_2_step_0': 0.1496841162443161, 'action_head.dit.layer_3_step_0': 0.19456493854522705, 'action_head.dit.layer_4_step_0': 0.21470099687576294, 'action_head.dit.layer_5_step_0': 0.26813650131225586, 'action_head.dit.layer_6_step_0': 0.26181918382644653, 'action_head.dit.layer_7_step_0': 0.27733632922172546, 'action_head.dit.layer_8_step_0': 0.2898782193660736, 'action_head.dit.layer_9_step_0': 0.3222406506538391, 'action_head.dit.layer_10_step_0': 0.3367379903793335, 'action_head.dit.layer_11_step_0': 0.36979392170906067, 'action_head.dit.layer_12_step_0': 0.32165390253067017, 'action_head.dit.layer_13_step_0': 0.34741923213005066, 'action_head.dit.layer_14_step_0': 0.36959439516067505, 'action_head.dit.layer_15_step_0': 0.33607202768325806, 'action_head.dit.layer_0_step_1': 0.15393701195716858, 'action_head.dit.layer_1_step_1': 0.150865375995636, 'action_head.dit.layer_2_step_1': 0.18738538026809692, 'action_head.dit.layer_3_step_1': 0.21857407689094543, 'action_head.dit.layer_4_step_1': 0.25851255655288696, 'action_head.dit.layer_5_step_1': 0.26940274238586426, 'action_head.dit.layer_6_step_1': 0.28805625438690186, 'action_head.dit.layer_7_step_1': 0.32949838042259216, 'action_head.dit.layer_8_step_1': 0.3489595353603363, 'action_head.dit.layer_9_step_1': 0.3678755462169647, 'action_head.dit.layer_10_step_1': 0.3878394067287445, 'action_head.dit.layer_11_step_1': 0.4437538683414459, 'action_head.dit.layer_12_step_1': 0.376192569732666, 'action_head.dit.layer_13_step_1': 0.38436925411224365, 'action_head.dit.layer_14_step_1': 0.40988752245903015, 'action_head.dit.layer_15_step_1': 0.37899836897850037, 'action_head.dit.layer_0_step_2': 0.17493140697479248, 'action_head.dit.layer_1_step_2': 0.21233892440795898, 'action_head.dit.layer_2_step_2': 0.23317556083202362, 'action_head.dit.layer_3_step_2': 0.2947877049446106, 'action_head.dit.layer_4_step_2': 0.33185306191444397, 'action_head.dit.layer_5_step_2': 0.38431617617607117, 'action_head.dit.layer_6_step_2': 0.40460625290870667, 'action_head.dit.layer_7_step_2': 0.45493149757385254, 'action_head.dit.layer_8_step_2': 0.4653993248939514, 'action_head.dit.layer_9_step_2': 0.5266144871711731, 'action_head.dit.layer_10_step_2': 0.5257531404495239, 'action_head.dit.layer_11_step_2': 0.5590577125549316, 'action_head.dit.layer_12_step_2': 0.44432446360588074, 'action_head.dit.layer_13_step_2': 0.46598517894744873, 'action_head.dit.layer_14_step_2': 0.4733395278453827, 'action_head.dit.layer_15_step_2': 0.39796507358551025, 'action_head.dit.layer_0_step_3': 0.3017385005950928, 'action_head.dit.layer_1_step_3': 0.3866038918495178, 'action_head.dit.layer_2_step_3': 0.44254472851753235, 'action_head.dit.layer_3_step_3': 0.49605593085289, 'action_head.dit.layer_4_step_3': 0.5088080167770386, 'action_head.dit.layer_5_step_3': 0.5485714077949524, 'action_head.dit.layer_6_step_3': 0.590221643447876, 'action_head.dit.layer_7_step_3': 0.6169156432151794, 'action_head.dit.layer_8_step_3': 0.6313708424568176, 'action_head.dit.layer_9_step_3': 0.6438949108123779, 'action_head.dit.layer_10_step_3': 0.662897527217865, 'action_head.dit.layer_11_step_3': 0.6895997524261475, 'action_head.dit.layer_12_step_3': 0.5517681241035461, 'action_head.dit.layer_13_step_3': 0.5718324780464172, 'action_head.dit.layer_14_step_3': 0.5656970739364624, 'action_head.dit.layer_15_step_3': 0.5042114853858948}



keys= []
values = []
for k, v in seen_vs_oracle_place.items():
    keys.append(k)
    values.append(v)

# 그래프 생성
ax.plot(keys, values, marker='o', linewidth=2, color='red', label='Frames ~ Place process')

# x축 라벨 설정 및 회전
ax.set_xticks(range(len(keys)))
ax.set_xticklabels(keys, rotation=90)

# 조건에 따라 x축 라벨 색상 지정
for i, label in enumerate(ax.get_xticklabels()):
    text = label.get_text()
    if 'llm' in text:
        label.set_color('red')  # llm이 포함된 경우 빨간색
    else:
        label.set_color('blue')  # 그 외는 파란색

plt.tight_layout()
plt.legend()
plt.show()

# %%
keys = []
values = []


# 그래프 생성
fig, ax = plt.subplots(figsize=(12, 6))
        


seen_vs_oracle_place = {'backbone.llm.layer_0_step_0': 0.5029518008232117, 'backbone.llm.layer_1_step_0': 0.5223961472511292, 'backbone.llm.layer_2_step_0': 0.8013736009597778, 'backbone.llm.layer_3_step_0': 0.7984004020690918, 'backbone.llm.layer_4_step_0': 0.7917571663856506, 'backbone.llm.layer_5_step_0': 0.778992235660553, 'backbone.llm.layer_6_step_0': 0.776147186756134, 'backbone.llm.layer_7_step_0': 0.7702391147613525, 'backbone.llm.layer_8_step_0': 0.7364890575408936, 'backbone.llm.layer_9_step_0': 0.7422598600387573, 'backbone.llm.layer_10_step_0': 0.720199704170227, 'backbone.llm.layer_11_step_0': 0.727385401725769, 'action_head.dit.layer_0_step_0': 0.11355985701084137, 'action_head.dit.layer_1_step_0': 0.14806637167930603, 'action_head.dit.layer_2_step_0': 0.1496841162443161, 'action_head.dit.layer_3_step_0': 0.19456493854522705, 'action_head.dit.layer_4_step_0': 0.21470099687576294, 'action_head.dit.layer_5_step_0': 0.26813650131225586, 'action_head.dit.layer_6_step_0': 0.26181918382644653, 'action_head.dit.layer_7_step_0': 0.27733632922172546, 'action_head.dit.layer_8_step_0': 0.2898782193660736, 'action_head.dit.layer_9_step_0': 0.3222406506538391, 'action_head.dit.layer_10_step_0': 0.3367379903793335, 'action_head.dit.layer_11_step_0': 0.36979392170906067, 'action_head.dit.layer_12_step_0': 0.32165390253067017, 'action_head.dit.layer_13_step_0': 0.34741923213005066, 'action_head.dit.layer_14_step_0': 0.36959439516067505, 'action_head.dit.layer_15_step_0': 0.33607202768325806, 'action_head.dit.layer_0_step_1': 0.15393701195716858, 'action_head.dit.layer_1_step_1': 0.150865375995636, 'action_head.dit.layer_2_step_1': 0.18738538026809692, 'action_head.dit.layer_3_step_1': 0.21857407689094543, 'action_head.dit.layer_4_step_1': 0.25851255655288696, 'action_head.dit.layer_5_step_1': 0.26940274238586426, 'action_head.dit.layer_6_step_1': 0.28805625438690186, 'action_head.dit.layer_7_step_1': 0.32949838042259216, 'action_head.dit.layer_8_step_1': 0.3489595353603363, 'action_head.dit.layer_9_step_1': 0.3678755462169647, 'action_head.dit.layer_10_step_1': 0.3878394067287445, 'action_head.dit.layer_11_step_1': 0.4437538683414459, 'action_head.dit.layer_12_step_1': 0.376192569732666, 'action_head.dit.layer_13_step_1': 0.38436925411224365, 'action_head.dit.layer_14_step_1': 0.40988752245903015, 'action_head.dit.layer_15_step_1': 0.37899836897850037, 'action_head.dit.layer_0_step_2': 0.17493140697479248, 'action_head.dit.layer_1_step_2': 0.21233892440795898, 'action_head.dit.layer_2_step_2': 0.23317556083202362, 'action_head.dit.layer_3_step_2': 0.2947877049446106, 'action_head.dit.layer_4_step_2': 0.33185306191444397, 'action_head.dit.layer_5_step_2': 0.38431617617607117, 'action_head.dit.layer_6_step_2': 0.40460625290870667, 'action_head.dit.layer_7_step_2': 0.45493149757385254, 'action_head.dit.layer_8_step_2': 0.4653993248939514, 'action_head.dit.layer_9_step_2': 0.5266144871711731, 'action_head.dit.layer_10_step_2': 0.5257531404495239, 'action_head.dit.layer_11_step_2': 0.5590577125549316, 'action_head.dit.layer_12_step_2': 0.44432446360588074, 'action_head.dit.layer_13_step_2': 0.46598517894744873, 'action_head.dit.layer_14_step_2': 0.4733395278453827, 'action_head.dit.layer_15_step_2': 0.39796507358551025, 'action_head.dit.layer_0_step_3': 0.3017385005950928, 'action_head.dit.layer_1_step_3': 0.3866038918495178, 'action_head.dit.layer_2_step_3': 0.44254472851753235, 'action_head.dit.layer_3_step_3': 0.49605593085289, 'action_head.dit.layer_4_step_3': 0.5088080167770386, 'action_head.dit.layer_5_step_3': 0.5485714077949524, 'action_head.dit.layer_6_step_3': 0.590221643447876, 'action_head.dit.layer_7_step_3': 0.6169156432151794, 'action_head.dit.layer_8_step_3': 0.6313708424568176, 'action_head.dit.layer_9_step_3': 0.6438949108123779, 'action_head.dit.layer_10_step_3': 0.662897527217865, 'action_head.dit.layer_11_step_3': 0.6895997524261475, 'action_head.dit.layer_12_step_3': 0.5517681241035461, 'action_head.dit.layer_13_step_3': 0.5718324780464172, 'action_head.dit.layer_14_step_3': 0.5656970739364624, 'action_head.dit.layer_15_step_3': 0.5042114853858948}



keys= []
values = []
for k, v in seen_vs_oracle_place.items():
    keys.append(k)
    values.append(v)

# 그래프 생성
ax.plot(keys, values, marker='o', linewidth=2, color='blue', label='Frames ~ Place process')

# x축 라벨 설정 및 회전
ax.set_xticks(range(len(keys)))
ax.set_xticklabels(keys, rotation=90)

# 조건에 따라 x축 라벨 색상 지정
for i, label in enumerate(ax.get_xticklabels()):
    text = label.get_text()
    if 'llm' in text:
        label.set_color('red')  # llm이 포함된 경우 빨간색
    else:
        label.set_color('blue')  # 그 외는 파란색

plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# # Pretrained vs Oracle

# %%
keys = []
values = []

full_vs_0 = {'backbone.llm.layer_0_step_0': 0.4213777482509613, 'backbone.llm.layer_1_step_0': 0.4404739439487457, 'backbone.llm.layer_2_step_0': 0.8347737193107605, 'backbone.llm.layer_3_step_0': 0.8342269659042358, 'backbone.llm.layer_4_step_0': 0.833403468132019, 'backbone.llm.layer_5_step_0': 0.815811276435852, 'backbone.llm.layer_6_step_0': 0.8096203207969666, 'backbone.llm.layer_7_step_0': 0.8115443587303162, 'backbone.llm.layer_8_step_0': 0.6876656413078308, 'backbone.llm.layer_9_step_0': 0.6892565488815308, 'backbone.llm.layer_10_step_0': 0.6867077350616455, 'backbone.llm.layer_11_step_0': 0.6869844198226929, 'action_head.dit.layer_0_step_0': 0.11733423918485641, 'action_head.dit.layer_1_step_0': 0.11179205775260925, 'action_head.dit.layer_2_step_0': 0.11270594596862793, 'action_head.dit.layer_3_step_0': 0.11447551101446152, 'action_head.dit.layer_4_step_0': 0.11037956178188324, 'action_head.dit.layer_5_step_0': 0.1127452477812767, 'action_head.dit.layer_6_step_0': 0.11387885361909866, 'action_head.dit.layer_7_step_0': 0.11090295016765594, 'action_head.dit.layer_8_step_0': 0.11098482459783554, 'action_head.dit.layer_9_step_0': 0.10839851945638657, 'action_head.dit.layer_10_step_0': 0.10839337855577469, 'action_head.dit.layer_11_step_0': 0.10891452431678772, 'action_head.dit.layer_12_step_0': 0.14753589034080505, 'action_head.dit.layer_13_step_0': 0.14940255880355835, 'action_head.dit.layer_14_step_0': 0.15021084249019623, 'action_head.dit.layer_15_step_0': 0.16513337194919586, 'action_head.dit.layer_0_step_1': 0.1142638623714447, 'action_head.dit.layer_1_step_1': 0.11087968945503235, 'action_head.dit.layer_2_step_1': 0.11113890260457993, 'action_head.dit.layer_3_step_1': 0.1130184754729271, 'action_head.dit.layer_4_step_1': 0.11315900832414627, 'action_head.dit.layer_5_step_1': 0.11060186475515366, 'action_head.dit.layer_6_step_1': 0.1120801791548729, 'action_head.dit.layer_7_step_1': 0.11273853480815887, 'action_head.dit.layer_8_step_1': 0.1100989505648613, 'action_head.dit.layer_9_step_1': 0.1122678816318512, 'action_head.dit.layer_10_step_1': 0.1386847347021103, 'action_head.dit.layer_11_step_1': 0.1324326992034912, 'action_head.dit.layer_12_step_1': 0.15094906091690063, 'action_head.dit.layer_13_step_1': 0.1513594090938568, 'action_head.dit.layer_14_step_1': 0.15140964090824127, 'action_head.dit.layer_15_step_1': 0.17019732296466827, 'action_head.dit.layer_0_step_2': 0.11820843070745468, 'action_head.dit.layer_1_step_2': 0.11297391355037689, 'action_head.dit.layer_2_step_2': 0.11356263607740402, 'action_head.dit.layer_3_step_2': 0.11573471873998642, 'action_head.dit.layer_4_step_2': 0.11313558369874954, 'action_head.dit.layer_5_step_2': 0.11603652685880661, 'action_head.dit.layer_6_step_2': 0.15050627291202545, 'action_head.dit.layer_7_step_2': 0.15520505607128143, 'action_head.dit.layer_8_step_2': 0.1522434502840042, 'action_head.dit.layer_9_step_2': 0.15455667674541473, 'action_head.dit.layer_10_step_2': 0.18553601205348969, 'action_head.dit.layer_11_step_2': 0.18540214002132416, 'action_head.dit.layer_12_step_2': 0.16793358325958252, 'action_head.dit.layer_13_step_2': 0.1731807440519333, 'action_head.dit.layer_14_step_2': 0.1769195944070816, 'action_head.dit.layer_15_step_2': 0.21073737740516663, 'action_head.dit.layer_0_step_3': 0.13875262439250946, 'action_head.dit.layer_1_step_3': 0.17461717128753662, 'action_head.dit.layer_2_step_3': 0.17913196980953217, 'action_head.dit.layer_3_step_3': 0.1854865998029709, 'action_head.dit.layer_4_step_3': 0.203466534614563, 'action_head.dit.layer_5_step_3': 0.20320886373519897, 'action_head.dit.layer_6_step_3': 0.20447281002998352, 'action_head.dit.layer_7_step_3': 0.20440924167633057, 'action_head.dit.layer_8_step_3': 0.22457462549209595, 'action_head.dit.layer_9_step_3': 0.2537934184074402, 'action_head.dit.layer_10_step_3': 0.2751566171646118, 'action_head.dit.layer_11_step_3': 0.32576870918273926, 'action_head.dit.layer_12_step_3': 0.35135844349861145, 'action_head.dit.layer_13_step_3': 0.3785074055194855, 'action_head.dit.layer_14_step_3': 0.4022239148616791, 'action_head.dit.layer_15_step_3': 0.6112781167030334}

for k, v in full_vs_0.items():
    keys.append(k)
    values.append(v)

# 그래프 생성
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(keys, values, marker='o', linewidth=2, label='15000 steps vs 0 step')

# x축 라벨 설정 및 회전
ax.set_xticks(range(len(keys)))
ax.set_xticklabels(keys, rotation=90)
        


full_vs_5000 = {'backbone.llm.layer_0_step_0': 0.47087278962135315, 'backbone.llm.layer_1_step_0': 0.4908468723297119, 'backbone.llm.layer_2_step_0': 0.858252227306366, 'backbone.llm.layer_3_step_0': 0.8586363196372986, 'backbone.llm.layer_4_step_0': 0.8579065203666687, 'backbone.llm.layer_5_step_0': 0.782453179359436, 'backbone.llm.layer_6_step_0': 0.7740176916122437, 'backbone.llm.layer_7_step_0': 0.7703927755355835, 'backbone.llm.layer_8_step_0': 0.7383420467376709, 'backbone.llm.layer_9_step_0': 0.7260972261428833, 'backbone.llm.layer_10_step_0': 0.7221609354019165, 'backbone.llm.layer_11_step_0': 0.7093195915222168, 'action_head.dit.layer_0_step_0': 0.11438526958227158, 'action_head.dit.layer_1_step_0': 0.11189410835504532, 'action_head.dit.layer_2_step_0': 0.11094319820404053, 'action_head.dit.layer_3_step_0': 0.15188726782798767, 'action_head.dit.layer_4_step_0': 0.18935883045196533, 'action_head.dit.layer_5_step_0': 0.19314144551753998, 'action_head.dit.layer_6_step_0': 0.2224503457546234, 'action_head.dit.layer_7_step_0': 0.22574083507061005, 'action_head.dit.layer_8_step_0': 0.24885070323944092, 'action_head.dit.layer_9_step_0': 0.27725309133529663, 'action_head.dit.layer_10_step_0': 0.2903432548046112, 'action_head.dit.layer_11_step_0': 0.3231024146080017, 'action_head.dit.layer_12_step_0': 0.2725042402744293, 'action_head.dit.layer_13_step_0': 0.2917364239692688, 'action_head.dit.layer_14_step_0': 0.2879847586154938, 'action_head.dit.layer_15_step_0': 0.2600269615650177, 'action_head.dit.layer_0_step_1': 0.11461002379655838, 'action_head.dit.layer_1_step_1': 0.11307401955127716, 'action_head.dit.layer_2_step_1': 0.1554555594921112, 'action_head.dit.layer_3_step_1': 0.1860927939414978, 'action_head.dit.layer_4_step_1': 0.18741938471794128, 'action_head.dit.layer_5_step_1': 0.22573092579841614, 'action_head.dit.layer_6_step_1': 0.2588709592819214, 'action_head.dit.layer_7_step_1': 0.2900417745113373, 'action_head.dit.layer_8_step_1': 0.31832417845726013, 'action_head.dit.layer_9_step_1': 0.3492791950702667, 'action_head.dit.layer_10_step_1': 0.35096052289009094, 'action_head.dit.layer_11_step_1': 0.3638835549354553, 'action_head.dit.layer_12_step_1': 0.2818715572357178, 'action_head.dit.layer_13_step_1': 0.3038162291049957, 'action_head.dit.layer_14_step_1': 0.32341185212135315, 'action_head.dit.layer_15_step_1': 0.283107191324234, 'action_head.dit.layer_0_step_2': 0.1431545615196228, 'action_head.dit.layer_1_step_2': 0.1827012151479721, 'action_head.dit.layer_2_step_2': 0.20673584938049316, 'action_head.dit.layer_3_step_2': 0.2641089856624603, 'action_head.dit.layer_4_step_2': 0.2959929406642914, 'action_head.dit.layer_5_step_2': 0.33193016052246094, 'action_head.dit.layer_6_step_2': 0.3693898022174835, 'action_head.dit.layer_7_step_2': 0.39555031061172485, 'action_head.dit.layer_8_step_2': 0.4074132740497589, 'action_head.dit.layer_9_step_2': 0.46774429082870483, 'action_head.dit.layer_10_step_2': 0.5013896226882935, 'action_head.dit.layer_11_step_2': 0.5234787464141846, 'action_head.dit.layer_12_step_2': 0.34922754764556885, 'action_head.dit.layer_13_step_2': 0.34980255365371704, 'action_head.dit.layer_14_step_2': 0.3854128420352936, 'action_head.dit.layer_15_step_2': 0.3345783054828644, 'action_head.dit.layer_0_step_3': 0.2746220827102661, 'action_head.dit.layer_1_step_3': 0.34060007333755493, 'action_head.dit.layer_2_step_3': 0.4138948917388916, 'action_head.dit.layer_3_step_3': 0.4632948338985443, 'action_head.dit.layer_4_step_3': 0.4854882061481476, 'action_head.dit.layer_5_step_3': 0.5224432349205017, 'action_head.dit.layer_6_step_3': 0.5597261786460876, 'action_head.dit.layer_7_step_3': 0.5863298177719116, 'action_head.dit.layer_8_step_3': 0.6162468791007996, 'action_head.dit.layer_9_step_3': 0.642495334148407, 'action_head.dit.layer_10_step_3': 0.6441434025764465, 'action_head.dit.layer_11_step_3': 0.6635438203811646, 'action_head.dit.layer_12_step_3': 0.4507589638233185, 'action_head.dit.layer_13_step_3': 0.46700868010520935, 'action_head.dit.layer_14_step_3': 0.48273494839668274, 'action_head.dit.layer_15_step_3': 0.5185555219650269}

keys= []
values = []
for k, v in full_vs_5000.items():
    keys.append(k)
    values.append(v)

# 그래프 생성
ax.plot(keys, values, marker='o', linewidth=2, color='red', label='15000 steps vs 5000 steps')

# x축 라벨 설정 및 회전
ax.set_xticks(range(len(keys)))
ax.set_xticklabels(keys, rotation=90)

# 조건에 따라 x축 라벨 색상 지정
for i, label in enumerate(ax.get_xticklabels()):
    text = label.get_text()
    if 'llm' in text:
        label.set_color('red')  # llm이 포함된 경우 빨간색
    else:
        label.set_color('blue')  # 그 외는 파란색
        
        

full_vs_10000 = {'backbone.llm.layer_0_step_0': 0.5301076769828796, 'backbone.llm.layer_1_step_0': 0.5504381656646729, 'backbone.llm.layer_2_step_0': 0.8217195272445679, 'backbone.llm.layer_3_step_0': 0.8225417137145996, 'backbone.llm.layer_4_step_0': 0.8226995468139648, 'backbone.llm.layer_5_step_0': 0.8140705227851868, 'backbone.llm.layer_6_step_0': 0.8098795413970947, 'backbone.llm.layer_7_step_0': 0.8081389665603638, 'backbone.llm.layer_8_step_0': 0.7784994840621948, 'backbone.llm.layer_9_step_0': 0.7712629437446594, 'backbone.llm.layer_10_step_0': 0.750575065612793, 'backbone.llm.layer_11_step_0': 0.833571195602417, 'action_head.dit.layer_0_step_0': 0.1150183230638504, 'action_head.dit.layer_1_step_0': 0.1592988222837448, 'action_head.dit.layer_2_step_0': 0.16305622458457947, 'action_head.dit.layer_3_step_0': 0.19598804414272308, 'action_head.dit.layer_4_step_0': 0.23327434062957764, 'action_head.dit.layer_5_step_0': 0.27169671654701233, 'action_head.dit.layer_6_step_0': 0.26387128233909607, 'action_head.dit.layer_7_step_0': 0.29949507117271423, 'action_head.dit.layer_8_step_0': 0.33415931463241577, 'action_head.dit.layer_9_step_0': 0.35722818970680237, 'action_head.dit.layer_10_step_0': 0.38762855529785156, 'action_head.dit.layer_11_step_0': 0.4070255756378174, 'action_head.dit.layer_12_step_0': 0.362302303314209, 'action_head.dit.layer_13_step_0': 0.3977135717868805, 'action_head.dit.layer_14_step_0': 0.4148738384246826, 'action_head.dit.layer_15_step_0': 0.39539122581481934, 'action_head.dit.layer_0_step_1': 0.16043983399868011, 'action_head.dit.layer_1_step_1': 0.1588287651538849, 'action_head.dit.layer_2_step_1': 0.19680581986904144, 'action_head.dit.layer_3_step_1': 0.2361641377210617, 'action_head.dit.layer_4_step_1': 0.2731238007545471, 'action_head.dit.layer_5_step_1': 0.29843848943710327, 'action_head.dit.layer_6_step_1': 0.3356398642063141, 'action_head.dit.layer_7_step_1': 0.3870355784893036, 'action_head.dit.layer_8_step_1': 0.4126361012458801, 'action_head.dit.layer_9_step_1': 0.4312494397163391, 'action_head.dit.layer_10_step_1': 0.4476035535335541, 'action_head.dit.layer_11_step_1': 0.4585249125957489, 'action_head.dit.layer_12_step_1': 0.41582486033439636, 'action_head.dit.layer_13_step_1': 0.4376944303512573, 'action_head.dit.layer_14_step_1': 0.4601293206214905, 'action_head.dit.layer_15_step_1': 0.41907384991645813, 'action_head.dit.layer_0_step_2': 0.18488937616348267, 'action_head.dit.layer_1_step_2': 0.25417304039001465, 'action_head.dit.layer_2_step_2': 0.2825351655483246, 'action_head.dit.layer_3_step_2': 0.33939629793167114, 'action_head.dit.layer_4_step_2': 0.37413498759269714, 'action_head.dit.layer_5_step_2': 0.4191487431526184, 'action_head.dit.layer_6_step_2': 0.45868295431137085, 'action_head.dit.layer_7_step_2': 0.47137388586997986, 'action_head.dit.layer_8_step_2': 0.5034436583518982, 'action_head.dit.layer_9_step_2': 0.5329264402389526, 'action_head.dit.layer_10_step_2': 0.5508331656455994, 'action_head.dit.layer_11_step_2': 0.5626926422119141, 'action_head.dit.layer_12_step_2': 0.5035983920097351, 'action_head.dit.layer_13_step_2': 0.514068067073822, 'action_head.dit.layer_14_step_2': 0.5472613573074341, 'action_head.dit.layer_15_step_2': 0.44505226612091064, 'action_head.dit.layer_0_step_3': 0.37161415815353394, 'action_head.dit.layer_1_step_3': 0.44173479080200195, 'action_head.dit.layer_2_step_3': 0.4736928343772888, 'action_head.dit.layer_3_step_3': 0.5195376873016357, 'action_head.dit.layer_4_step_3': 0.5329997539520264, 'action_head.dit.layer_5_step_3': 0.5724517703056335, 'action_head.dit.layer_6_step_3': 0.5978323221206665, 'action_head.dit.layer_7_step_3': 0.6049517393112183, 'action_head.dit.layer_8_step_3': 0.6396230459213257, 'action_head.dit.layer_9_step_3': 0.6753568053245544, 'action_head.dit.layer_10_step_3': 0.677173912525177, 'action_head.dit.layer_11_step_3': 0.6976990103721619, 'action_head.dit.layer_12_step_3': 0.5891581773757935, 'action_head.dit.layer_13_step_3': 0.6063282489776611, 'action_head.dit.layer_14_step_3': 0.6154870390892029, 'action_head.dit.layer_15_step_3': 0.5886765718460083}

keys= []
values = []
for k, v in full_vs_10000.items():
    keys.append(k)
    values.append(v)

# 그래프 생성
ax.plot(keys, values, marker='o', linewidth=2, color='orange', label='15000 steps vs 10000 steps')

# x축 라벨 설정 및 회전
ax.set_xticks(range(len(keys)))
ax.set_xticklabels(keys, rotation=90)

# 조건에 따라 x축 라벨 색상 지정
for i, label in enumerate(ax.get_xticklabels()):
    text = label.get_text()
    if 'llm' in text:
        label.set_color('red')  # llm이 포함된 경우 빨간색
    else:
        label.set_color('blue')  # 그 외는 파란색

plt.tight_layout()
plt.legend()
plt.show()

# %%
keys = []
values = []

pretrained_vs_finetuned = {'backbone.llm.layer_0_step_0': 0.42411115765571594, 'backbone.llm.layer_1_step_0': 0.4454880952835083, 'backbone.llm.layer_2_step_0': 0.753056526184082, 'backbone.llm.layer_3_step_0': 0.7521619200706482, 'backbone.llm.layer_4_step_0': 0.7517058849334717, 'backbone.llm.layer_5_step_0': 0.736548662185669, 'backbone.llm.layer_6_step_0': 0.7305257320404053, 'backbone.llm.layer_7_step_0': 0.7242913246154785, 'backbone.llm.layer_8_step_0': 0.683856725692749, 'backbone.llm.layer_9_step_0': 0.6906912922859192, 'backbone.llm.layer_10_step_0': 0.7574591636657715, 'backbone.llm.layer_11_step_0': 0.732498824596405, 'action_head.dit.layer_0_step_0': 0.10282675176858902, 'action_head.dit.layer_1_step_0': 0.1028132364153862, 'action_head.dit.layer_2_step_0': 0.10180546343326569, 'action_head.dit.layer_3_step_0': 0.10264786332845688, 'action_head.dit.layer_4_step_0': 0.10319516062736511, 'action_head.dit.layer_5_step_0': 0.10446138679981232, 'action_head.dit.layer_6_step_0': 0.10690723359584808, 'action_head.dit.layer_7_step_0': 0.10432235151529312, 'action_head.dit.layer_8_step_0': 0.10458356887102127, 'action_head.dit.layer_9_step_0': 0.10524944216012955, 'action_head.dit.layer_10_step_0': 0.10589276999235153, 'action_head.dit.layer_11_step_0': 0.1063309833407402, 'action_head.dit.layer_12_step_0': 0.14279793202877045, 'action_head.dit.layer_13_step_0': 0.14324821531772614, 'action_head.dit.layer_14_step_0': 0.14403784275054932, 'action_head.dit.layer_15_step_0': 0.15713104605674744, 'action_head.dit.layer_0_step_1': 0.1056433618068695, 'action_head.dit.layer_1_step_1': 0.10445471853017807, 'action_head.dit.layer_2_step_1': 0.1030580997467041, 'action_head.dit.layer_3_step_1': 0.103238545358181, 'action_head.dit.layer_4_step_1': 0.10472988337278366, 'action_head.dit.layer_5_step_1': 0.10568808019161224, 'action_head.dit.layer_6_step_1': 0.10448803752660751, 'action_head.dit.layer_7_step_1': 0.10588496923446655, 'action_head.dit.layer_8_step_1': 0.1067066490650177, 'action_head.dit.layer_9_step_1': 0.1071355864405632, 'action_head.dit.layer_10_step_1': 0.1309022456407547, 'action_head.dit.layer_11_step_1': 0.12993183732032776, 'action_head.dit.layer_12_step_1': 0.1439017653465271, 'action_head.dit.layer_13_step_1': 0.14445258677005768, 'action_head.dit.layer_14_step_1': 0.14464424550533295, 'action_head.dit.layer_15_step_1': 0.1584358662366867, 'action_head.dit.layer_0_step_2': 0.10861562937498093, 'action_head.dit.layer_1_step_2': 0.10863091796636581, 'action_head.dit.layer_2_step_2': 0.11009007692337036, 'action_head.dit.layer_3_step_2': 0.111039899289608, 'action_head.dit.layer_4_step_2': 0.10916602611541748, 'action_head.dit.layer_5_step_2': 0.1108434870839119, 'action_head.dit.layer_6_step_2': 0.11434254050254822, 'action_head.dit.layer_7_step_2': 0.15042895078659058, 'action_head.dit.layer_8_step_2': 0.1477956622838974, 'action_head.dit.layer_9_step_2': 0.14747290313243866, 'action_head.dit.layer_10_step_2': 0.17484387755393982, 'action_head.dit.layer_11_step_2': 0.1748829185962677, 'action_head.dit.layer_12_step_2': 0.1588616669178009, 'action_head.dit.layer_13_step_2': 0.16424262523651123, 'action_head.dit.layer_14_step_2': 0.16454537212848663, 'action_head.dit.layer_15_step_2': 0.19621515274047852, 'action_head.dit.layer_0_step_3': 0.14102716743946075, 'action_head.dit.layer_1_step_3': 0.1654113382101059, 'action_head.dit.layer_2_step_3': 0.16810385882854462, 'action_head.dit.layer_3_step_3': 0.18438389897346497, 'action_head.dit.layer_4_step_3': 0.20025472342967987, 'action_head.dit.layer_5_step_3': 0.2040235698223114, 'action_head.dit.layer_6_step_3': 0.19485174119472504, 'action_head.dit.layer_7_step_3': 0.1967797577381134, 'action_head.dit.layer_8_step_3': 0.21947413682937622, 'action_head.dit.layer_9_step_3': 0.24927349388599396, 'action_head.dit.layer_10_step_3': 0.30045825242996216, 'action_head.dit.layer_11_step_3': 0.3212209939956665, 'action_head.dit.layer_12_step_3': 0.31928551197052, 'action_head.dit.layer_13_step_3': 0.333840548992157, 'action_head.dit.layer_14_step_3': 0.3432983458042145, 'action_head.dit.layer_15_step_3': 0.5105275511741638}

for k, v in pretrained_vs_finetuned.items():
    keys.append(k)
    values.append(v)

# 그래프 생성
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(keys, values, marker='o', linewidth=2)

# x축 라벨 설정 및 회전
ax.set_xticks(range(len(keys)))
ax.set_xticklabels(keys, rotation=90)

# 조건에 따라 x축 라벨 색상 지정
for i, label in enumerate(ax.get_xticklabels()):
    text = label.get_text()
    if 'llm' in text:
        label.set_color('red')  # llm이 포함된 경우 빨간색
    else:
        label.set_color('blue')  # 그 외는 파란색

plt.tight_layout()
plt.show()
